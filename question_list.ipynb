# %%
import json

data = {}

with open("qa.txt", "r") as rf:
    for rl in rf.readlines():
        rls = rl.rstrip("\n").split("\t")
        data[rls[0]] = rls[-1].split(",")

# 替换掉后面的内容，然后执行
input_value = {"status":1,"msg":"success","data":{"token":"1c52486ff0b2a44fbfefeb15d21f53ae","questions":[{"question_id":"144","type":"1","title":"2019年是新中国成立70周年，在世界舞台上，2019年堪称是中国的主场：“一带一路”国际合作高峰论坛、世界园艺博览会、世界军人运动会、中国国际进口博览会等都在中国召开。这说明(  )。","answer":["A.中国的发展为世界各国提供了更宝贵的合作契机","B.中国担当向世界展现了大国风范，显示了中国智慧","C.中国在世界政治、经济、文化等多领域日益发挥着重要影响","D.世界向着公平公正、多元共治、包容有序的格局发展"]},{"question_id":"994","type":"1","title":"1956年9月，党的八大确定（ ）为繁荣科学和文化艺术工作的指导方针。","answer":["A.百花齐放 百家争鸣","B.民族的 科学的 大众的","C.古为今用 洋为中用","D.为人民服务 为社会主义服务"]},{"question_id":"259","type":"1","title":"1938年5月底6月初，毛泽东在延安正式作了（  ）长篇讲演，有力地批驳了社会上弥漫的“亡国论”“速胜论”等错误论调，坚定了全国人民抗战必胜的信心。","answer":["A.《新民主主义论》","B.《论十大关系》","C.《正确处理人民内部矛盾》","D.《论持久战》"]},{"question_id":"859","type":"2","title":"标志着中国人民局部抗日战争开始和全面抗日战争开始的历史事件分别是(  )。","answer":["A.九一八事变","B.西安事变","C.七七事变","D.八一三事变"]},{"question_id":"875","type":"2","title":"下列措施中体现了中共十八大以来，中国与世界其他各国携手建设持久和平、共同繁荣的和谐世界的美好愿景的有(  )。","answer":["A.深入实施“一带一路”建设","B.筹建和成立亚洲基础设施投资银行","C.推进人民币国际化进程","D.中国加入世界贸易组织"]}],"ref":"https:\/\/h5.btime.com\/Page\/jd100challenge"}}

questions = input_value["data"]["questions"]

for question in questions:
    question_id = question["question_id"]
    question_title = question["title"]
    question_answer = question["answer"]

    essence = data.get(question_id, None)
    if essence:
        print(essence)
# Out:
# ['C.中国在世界政治、经济、文化等多领域日益发挥着重要影响']
# ['A.百花齐放 百家争鸣']
# ['D.《论持久战》']
# ['A.九一八事变', 'C.七七事变']
# ['A.深入实施“一带一路”建设', 'B.筹建和成立亚洲基础设施投资银行', 'C.推进人民币国际化进程']
